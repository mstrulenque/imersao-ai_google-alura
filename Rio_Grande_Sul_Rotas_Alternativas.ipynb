# %% [markdown]
# <a href="https://colab.research.google.com/github/mstrulenque/imersao-ai_google-alura/blob/main/Rio_Grande_Sul_Rotas_Alternativas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto - Rio Grande do Sul - Estradas Alternativas (devido catastrofes climáticas)

# %% [markdown]
# ## 🛠 Configurações

# %% [markdown]
# ### ⚙ - Instalação SDK Python para API GEMINI

# %%
# !pip install -U -q google-generativeai
# Out:
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (3.6)

# %% [markdown]
# ### 📦 - Import das Bibliotecas utilizadas
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) pandas - Tratar Dados Estradas Alternativas em arquivo csv no GitHub
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  b) numpy - dados matemáticos - embedded
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  c) google.generativeai - utilizacao da API Google
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  d) userdata - Google Colab - recuperação da chave secreta - API Key

# %%
import pandas as pd
import numpy as np
import google.generativeai as genai
from google.colab import userdata

# %% [markdown]
# ### - Varíaveis que serão utilizadas

# %%
model = "models/embedding-001"
GOOGLE_API_KEY = userdata.get('secret_api_key')

# %% [markdown]
# ### 🔐 - Setar a API_KEY para a API Gemini.
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Para isto:
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Recuperar a sua API_KEY armazenada no Secrets do Colab
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; b) Setar a api_key para utilizar a API Gemini com o conteúdo recuperado da Secret

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %% [markdown]
# ## ⚙ - Funções
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Embedding - Dados Estradas Alternativas
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; b) Embedding - Prompt
# #####&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; c) Retorno Prompt (Modelo identificando Resposta mais Provavel)

# %%
def embed_origem_dados(title, text):

  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
def embed_prompt(prompt):

  return genai.embed_content(model=model,
                                 content=prompt,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

# %%
def retorno_prompt (prompt_embed):
  produtos_escalares = np.dot(np.stack(df["Embeddings"]), prompt_embed)

  return  np.argmax(produtos_escalares)

# %% [markdown]
# ### 📁 - Dados - Carregando CSV do GitHub para o Pandas e Fazendo o Embedded dos **Dados**

# %%
#------------------------------------------------------------------------------------------------------------
# Carregando o CSV com Dados, que estão no GitHub, com as Rotas Alternativas de Estradas do Rio Grande do Sul
#------------------------------------------------------------------------------------------------------------

dados_estradas = pd.read_csv('https://raw.githubusercontent.com/mstrulenque/imersao-ai_google-alura/main/RGS_Estradas-Alternativas.csv')

dados_estradas = dados_estradas.fillna(value='-')

df = pd.DataFrame(dados_estradas)

#------------------------------------------------------------------------------------------------------------
# Fazendo o Embedding dos dados e adicionando no dataframe
#------------------------------------------------------------------------------------------------------------

df["Embeddings"] = df.apply(lambda row: embed_origem_dados(row["Titulo"], row["Descricao"]), axis=1)
df
len(df)
# Out:
#                                         Titulo                  Origem  \
# 0                       PORTO ALEGRE x PELOTAS            PORTO ALEGRE
# 1                       CAXIAS DO SUL x TORRES           CAXIAS DO SUL
# 2                CAXIAS DO SUL x ANTONIO PRADO           CAXIAS DO SUL
# 19  Estradas Alternativas \nRotas Alternativas no ...
# 20  Estradas Alternativas \nRotas Alternativas no ...
# 21  Estradas Alternativas \nRotas Alternativas no ...
# 22  Estradas Alternativas \nRotas Alternativas no ...
# 23  Estradas Alternativas \nRotas Alternativas no ...
# 24  Estradas Alternativas \nRotas Alternativas no ...
# 25  Estradas Alternativas \nRotas Alternativas no ...
# 26  Estradas Alternativas \nRotas Alternativas no ...
# 27  Estradas Alternativas \nRotas Alternativas no ...
# 28  Estradas Alternativas \nRotas Alternativas no ...
# 29  Estradas Alternativas \nRotas Alternativas no ...
# 30  Estradas Alternativas \nRotas Alternativas no ...
# 31  Estradas Alternativas \nRotas Alternativas no ...
# 32  Estradas Alternativas \nRotas Alternativas no ...
# 33  Estradas Alternativas \nRotas Alternativas no ...
# 34  Estradas Alternativas \nRotas Alternativas no ...
# 35  Estradas Alternativas \nRotas Alternativas no ...
# 36  Estradas Alternativas \nRotas Alternativas no ...
# 37  Estradas Alternativas \nRotas Alternativas no ...
# 38  Estradas Alternativas \nRotas Alternativas no ...
# 39  Estradas Alternativas \nRotas Alternativas no ...
# 40  Estradas Alternativas \nRotas Alternativas no ...
# 41  Estradas Alternativas \nRotas Alternativas no ...
# 42  Estradas Alternativas \nRotas Alternativas no ...
# 43  Estradas Alternativas \nRotas Alternativas no ...
#
#                                                Rota_1  \
# 0   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 1   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 2   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 3   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 4   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 5   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 6   https://www.google.com/maps/d/u/0/viewer?hl=pt...
# 7   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 8   https://www.google.com/maps/d/u/0/viewer?hl=pt...
# 9   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 10  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 11  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 12  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 13  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 14  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 15  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 16  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 17  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 18  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 19  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 20  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 21  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 22  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 23  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 24  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 25  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 26  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 27  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 28  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 29  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 30  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 31  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 32  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 33  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 34  https://www.google.com/maps/d/u/0/viewer?hl=pt...
# 35  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 36  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 37  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 38  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 39  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 40  https://www.google.com/maps/d/u/0/viewer?hl=pt...
# 41  https://www.google.com/maps/d/u/0/viewer?hl=pt...
# 42  https://www.google.com/maps/d/u/0/viewer?hl=pt...
# 43  https://www.google.com/maps/d/u/0/viewer?hl=pt...
#
#                                                Rota_2  \
# 0   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 1                                                   -
# 2                                                   -
# 3                                                   -
# 4   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 5                                                   -
# 6                                                   -
# 7                                                   -
# 8                                                   -
# 9   https://www.google.com/maps/d/u/0/viewer?mid=1...
# 10  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 11  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 12                                                  -
# 13                                                  -
# 14                                                  -
# 15                                                  -
# 16                                                  -
# 17                                                  -
# 18                                                  -
# 19  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 20                                                  -
# 21                                                  -
# 22  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 23  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 24                                                  -
# 25  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 26                                                  -
# 27  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 28  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 29                                                  -
# 30  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 31                                                  -
# 32                                                  -
# 33                                                  -
# 34                                                  -
# 35                                                  -
# 36                                                  -
# 37                                                  -
# 38  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 39  https://www.google.com/maps/d/u/0/viewer?mid=1...
# 40                                                  -
# 41                                                  -
# 42                                                  -
# 43                                                  -
#
#                                            Embeddings
# 0   [0.0343332, -0.020739928, -0.054037448, -0.001...
# 1   [0.047652483, -0.03864447, -0.072944306, 0.002...
# 2   [0.022383068, -0.0048221084, -0.06283758, 0.01...
# 3   [0.033425327, -0.004956781, -0.06549962, 0.041...
# 4   [0.012001645, 0.0023293402, -0.056650717, 0.01...
# 5   [0.018111704, -0.017075466, -0.08223705, 0.020...
# 6   [0.015834913, -0.0051031574, -0.08427617, 0.02...
# 7   [0.02286368, -0.00034507827, -0.08307485, 0.01...
# 8   [0.04093417, -0.041495364, -0.08655137, 0.0042...
# 9   [0.015319292, -0.026149862, -0.05292116, 0.020...
# 10  [0.04951057, -0.0025115244, -0.083669886, -0.0...
# 11  [0.016231902, -0.022018798, -0.06893904, 0.002...
# 12  [0.037597075, -0.01959378, -0.07194905, 0.0037...
# 13  [0.046778433, -0.022799566, -0.046152975, 0.00...
# 14  [0.024384804, -0.042266417, -0.06414463, 0.011...
# 15  [0.028685212, -0.04050535, -0.07383697, -0.008...
# 16  [0.025152793, -0.04141538, -0.06736196, -0.005...
# 17  [0.009497022, -0.0029943099, -0.03230266, 0.03...
# 18  [0.010212355, -0.016744968, -0.054251615, 0.02...
# 19  [0.03758664, -0.022833742, -0.08212051, -0.016...
# 20  [0.033093456, -0.021537567, -0.085414365, -0.0...
# 21  [0.028631063, -0.024540007, -0.075661354, -0.0...
# 22  [0.015585411, -0.02564434, -0.061808635, 0.012...
# 23  [0.015585411, -0.02564434, -0.061808635, 0.012...
# 24  [0.030249026, -0.014282665, -0.09088514, 0.018...
# 25  [0.030086702, -0.043954812, -0.07009075, 0.012...
# 26  [0.004391824, -0.0380722, -0.068689816, 0.0035...
# 27  [0.02644184, -0.035072118, -0.077982835, 0.005...
# 28  [0.0135006765, -0.033693034, -0.08491368, 0.00...
# 29  [0.025933933, -0.017397897, -0.08103766, 0.014...
# 30  [0.015282145, -0.009545235, -0.063697435, 0.00...
# 31  [0.028325308, -0.022633582, -0.093185864, 0.00...
# 32  [0.031990997, -0.038799353, -0.051913083, 0.00...
# 33  [0.010540991, -0.015689708, -0.07896214, -0.01...
# 34  [0.015267142, -0.0309985, -0.06835281, 0.00396...
# 35  [0.021083541, -0.00986806, -0.07239074, 0.0268...
# 36  [0.025936488, -0.038887933, -0.08978107, 0.017...
# 37  [0.014629832, -0.017634055, -0.080147244, -0.0...
# 38  [0.03880033, -0.050433926, -0.06926117, 0.0127...
# 39  [0.010378928, -0.030929696, -0.08003399, 0.015...
# 40  [0.03307789, -0.033597894, -0.084409, 0.004348...
# 41  [0.037356034, -0.03381269, -0.076020055, 0.014...
# 42  [0.025680596, -0.028936448, -0.05835689, -0.00...
# 43  [0.02078659, -0.03859048, -0.054065958, -0.004...

# %%
# Out:
# 44

# %% [markdown]
# # 🧠 PROMPT :

# %%
#####################################################################################
# INPUT - PROMPT
#####################################################################################
cabecalho = ""
cabecalho = cabecalho + "++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n"
cabecalho = cabecalho + "+ RIO GRANDE DO SUL\n"
cabecalho = cabecalho + "+ Estradas Alternativas Devido Catastrofe Climática \n"
cabecalho = cabecalho + "++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n\n"
cabecalho = cabecalho + " Digite o Prompt e aperte o <Enter> \n"
cabecalho = cabecalho + " Exemplo Prompt: qual estrada de caxias para torres? \n"
cabecalho = cabecalho + f" (Total Trechos de Estradas: {len(df)}) \n"
cabecalho = cabecalho + "................................................................................................................ \n"
print(cabecalho)

print("💬")
prompt = input("PROMPT : ")

#####################################################################################
# PROMPT - EMBEDING + PESQUISA
#####################################################################################

prompt_embed = embed_prompt(prompt)
indice = retorno_prompt(prompt_embed)

#####################################################################################
# RESPOSTA
#####################################################################################

resposta = "\n\n"

resposta = resposta + '================================================================================================================\n'
resposta = resposta + ' 🧠 RESPONSE: \n'
resposta = resposta + '================================================================================================================ \n\n'

resposta = resposta + f'  . ORIGEM: {df.iloc[indice]["Origem"]} \n'
resposta = resposta + f'  . DESTINO: {df.iloc[indice]["Destino"]} \n\n'

resposta = resposta + '    ............................................................................................................ \n'
resposta = resposta + '  . 🚗 ROTAS ALTERNATIVAS - GOOGLE MAPAS: \n'
resposta = resposta + '    ............................................................................................................ \n'
resposta = resposta +  f'   📌 Rota 1: {df.iloc[indice]["Rota_1"]} \n'
resposta = resposta +  f'   📌 Rota 2: {df.iloc[indice]["Rota_2"]} \n'
resposta = resposta + '================================================================================================================ \n'
resposta = resposta + f' (Data da Atualização deste Informação: {df.iloc[indice]["Atualizacao"]}) \n'

#resposta = resposta + ' Sentimos muito o sofrimento dos moradores do Rio Grande do Sul \n'
#resposta = resposta + ' Esperamos que tudo se resolva da melhor forma possível \n'
#resposta = resposta + '================================================================================================================ \n'

print(resposta)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# + RIO GRANDE DO SUL
# + Estradas Alternativas Devido Catastrofe Climática
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Digite o Prompt e aperte o <Enter>
#  Exemplo Prompt: qual estrada de caxias para torres?
#  (Total Trechos de Estradas: 44)
# ................................................................................................................
#
# 💬
# PROMPT : ricardo
#
#
# ================================================================================================================
#  # 🧠 RESPONSE:
# ================================================================================================================
#
#   . ORIGEM: DOUTOR RICARDO
#   . DESTINO: PORTO ALEGRE
#
#     ............................................................................................................
#   . 🚗 ROTAS ALTERNATIVAS - GOOGLE MAPAS:
#     ............................................................................................................
#    📌 Rota 1: https://www.google.com/maps/d/u/0/viewer?mid=1evcSsIN3jpZcX_EcPHWjjwS5fbKh5k4&ll=-30.364753735473062%2C-54.330658451729846&z=6
#    📌 Rota 2: https://www.google.com/maps/d/u/0/viewer?mid=1MS3XWIhKzqr2Ax9h2xjU8VhCsQ6EVrc&ll=-30.364753735473062%2C-54.330658451729846&z=6
# ================================================================================================================
#  (Data da Atualização deste Informação: 09/05/2024 12:19)
